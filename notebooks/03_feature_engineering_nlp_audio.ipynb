# %% [markdown]
# # 03 Feature Engineering: NLP and Audio
# Create audio helper scores, lyric sentiment/topic features, and HMM POS features.

# %%
import pandas as pd
from src.features.audio_features import add_audio_helper_scores
from src.features.lyric_features import add_lyric_features
from src.features.pos_hmm_viterbi import add_pos_features

df = pd.read_csv('../examples/sample_tracks.csv')
features = add_pos_features(add_lyric_features(add_audio_helper_scores(df)))
features.head()
