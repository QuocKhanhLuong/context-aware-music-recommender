# %% [markdown]
# # 05 Recommendation Demo
# Run the scenario ranker and hybrid recommender on sample data.

# %%
import pandas as pd
from src.models.scenario_ranker import ScenarioRanker

df = pd.read_csv('../examples/sample_tracks.csv')
ScenarioRanker().fit(df).recommend('study', top_k=5)[['track_name','artist','scenario_score','explanations']]
