# %% [markdown]
# # 01 Data Collection and Integration
# Load the offline track dataset and scraped Billboard chart snapshot, then normalize columns and join chart features.

# %%
import pandas as pd
from src.data.load_data import load_tracks_dataset, load_scraped_chart_dataset
from src.data.integrate_data import merge_music_and_chart_data

tracks = load_tracks_dataset('../examples/sample_tracks.csv')
chart = load_scraped_chart_dataset('../examples/sample_billboard_scraped.csv')
tracks.head(), chart.head()
