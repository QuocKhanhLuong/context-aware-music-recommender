# %% [markdown]
# # 02 EDA and Visualization
# Produce distributions, correlations, chi-square tests, scatter plots, bar charts, treemaps, and parallel-coordinate views.

# %%
import pandas as pd
from src.visualization.eda_plots import pearson_correlation_matrix, chi_square_test

df = pd.read_csv('../examples/sample_tracks.csv')
pearson_correlation_matrix(df)
