# %% [markdown]
# # 04 Model Training and Evaluation
# Train scenario classifiers and evaluate them with holdout and cross-validation metrics.

# %%
import pandas as pd
from src.features.emotion_features import create_weak_scenario_label
from src.models.scenario_classifier import ScenarioClassifier

df = create_weak_scenario_label(pd.read_csv('../examples/sample_tracks.csv'))
model = ScenarioClassifier(model_type='logistic_regression', tune=False).fit(df)
model.predict(df.head())
